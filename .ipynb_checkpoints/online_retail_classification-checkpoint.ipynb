# %% [markdown]
# # Online Retail Classification and Clustering using K-Means Clustering Algorithm

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Importing the Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Get the dataset

# %%
dataset = pd.read_excel('Online Retail.xlsx')

# %%
dataset.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# ### Filter out cancelled transactions (InvoiceNo starting with 'C')

# %%
# Filter out cancelled transactions (InvoiceNo starting with 'C')
def filterValidTransaction(invoiceNo):
    invoiceNo = str(invoiceNo)
    if invoiceNo.startswith('C'):
        return False
    else: return True

filtered_dataset = dataset[dataset['InvoiceNo'].apply(filterValidTransaction)]

# %%
filtered_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 532621 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    532621 non-null  object
#  1   StockCode    532621 non-null  object
#  2   Description  531167 non-null  object
#  3   Quantity     532621 non-null  int64
#  4   InvoiceDate  532621 non-null  datetime64[ns]
#  5   UnitPrice    532621 non-null  float64
#  6   CustomerID   397924 non-null  float64
#  7   Country      532621 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.6+ MB

# %% [markdown]
# ### Get the total number of customers that made valid transactions over the year

# %%
customer_count = len(filtered_dataset['CustomerID'].unique())
print(customer_count)
# Out:
# 4340

# %% [markdown]
# ### Get the total number of valid transactions

# %%
valid_transaction_count = len(filtered_dataset['InvoiceDate'].unique())
print(valid_transaction_count)
# Out:
# 19990

# %%
filtered_dataset=filtered_dataset.drop('Description', axis=1)

# %% [markdown]
# ### Get unique customer countries

# %%
filtered_dataset['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Bahrain', 'Israel', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# ### Create an aggregated variable named Amount, by multiplying Quantity with Price

# %%
filtered_dataset['Amount'] = filtered_dataset['Quantity']*filtered_dataset['UnitPrice']

# %% [markdown]
# ### Separate the variable InvoiceDate into two variables Date and Time

# %%
filtered_dataset['Date']=filtered_dataset['InvoiceDate'].dt.date
filtered_dataset['Time']=filtered_dataset['InvoiceDate'].dt.time

# %% [markdown]
# ### Filter out any transactions that do not have CustomerID associated with it

# %%
filtered_dataset = filtered_dataset.dropna(subset='CustomerID')

# %%
filtered_dataset.count()
# Out:
# InvoiceNo      397924
# StockCode      397924
# Quantity       397924
# InvoiceDate    397924
# UnitPrice      397924
# CustomerID     397924
# Country        397924
# Amount         397924
# Date           397924
# Time           397924
# dtype: int64

# %%
filtered_dataset = filtered_dataset.sort_values(by=['CustomerID'])

# %%
filtered_dataset.head()
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 61619     541431     23166     74215 2011-01-18 10:01:00       1.04
# 286633    562032    47559B        10 2011-08-02 08:48:00       1.25
# 286627    562032     22372         4 2011-08-02 08:48:00       4.25
# 286638    562032     23175         4 2011-08-02 08:48:00       3.25
# 286637    562032     22423         3 2011-08-02 08:48:00      12.75
#
#         CustomerID         Country    Amount        Date      Time
# 61619      12346.0  United Kingdom  77183.60  2011-01-18  10:01:00
# 286633     12347.0         Iceland     12.50  2011-08-02  08:48:00
# 286627     12347.0         Iceland     17.00  2011-08-02  08:48:00
# 286638     12347.0         Iceland     13.00  2011-08-02  08:48:00
# 286637     12347.0         Iceland     38.25  2011-08-02  08:48:00

# %% [markdown]
# ### Generate a RFM (Recency, Frequency, Monetary) Model for our target data

# %%
# Calculate the most recent date in the dataset
latest_date = filtered_dataset["Date"].max()

# %%
rfm = filtered_dataset.groupby("CustomerID").agg(
    FirstPurchase=("Date", lambda x: x.min().strftime("%m")), # First Purchase (Month)
    Recency=("Date", lambda x: round((latest_date - x.max()).days/30)),  # Months since last purchase
    Frequency=("InvoiceNo", "nunique"),  # Number of unique transactions
    Monetary=("Amount", "sum"),  # Total spending
    Min=("Amount", "min"), # Minimum Spending
    Median=("Amount", "median"), # Median Spending
    Max=("Amount", "max") # Maximum Spending
).reset_index()

# %%
rfm.head()
# Out:
#    CustomerID FirstPurchase  Recency  Frequency  Monetary       Min    Median  \
# 0     12346.0            01       11          1  77183.60  77183.60  77183.60
# 1     12347.0            12        0          7   4310.00      5.04     17.00
# 2     12348.0            12        2          4   1797.24     13.20     41.76
# 3     12349.0            11        1          1   1757.55      6.64     17.70
# 4     12350.0            02       10          1    334.40      8.50     19.80
#
#        Max
# 0  77183.6
# 1    249.6
# 2    240.0
# 3    300.0
# 4     40.0

# %% [markdown]
# ### Exploratory Data Analysis

# %%
sns.displot(data=rfm, x="Recency", kde=True)

# %%
sns.displot(data=rfm, x="Frequency", height=10, aspect=2)

# %%
sns.displot(data=rfm, x="Monetary", height=10)

# %%
rfm.describe()
# Out:
#          CustomerID      Recency    Frequency       Monetary           Min  \
# count   4339.000000  4339.000000  4339.000000    4339.000000   4339.000000
# mean   15299.936852     3.044711     4.271952    2053.793018     31.802077
# std     1721.889758     3.346080     7.705493    8988.248381   1175.818632
# min    12346.000000     0.000000     1.000000       0.000000      0.000000
# 25%    13812.500000     1.000000     1.000000     307.245000      0.950000
# 50%    15299.000000     2.000000     2.000000     674.450000      5.040000
# 75%    16778.500000     5.000000     5.000000    1661.640000      9.950000
# max    18287.000000    12.000000   210.000000  280206.020000  77183.600000
#
#              Median            Max
# count   4339.000000    4339.000000
# mean      46.527128     188.538550
# std     1178.071936    2891.147844
# min        0.000000       0.000000
# 25%        8.565000      31.800000
# 50%       15.750000      53.100000
# 75%       18.000000     103.680000
# max    77183.600000  168469.600000

# %% [markdown]
# ### Remove Outliers from the data

# %%
rfm = rfm[rfm['Frequency'] < 30]
rfm = rfm[rfm['Monetary'] < 20000]

# %%
rfm.describe()
# Out:
#          CustomerID      Recency    Frequency      Monetary          Min  \
# count   4272.000000  4272.000000  4272.000000   4272.000000  4272.000000
# mean   15302.237828     3.081695     3.672519   1360.097995    13.410188
# std     1720.023060     3.347035     3.951025   1960.563375    92.116770
# min    12347.000000     0.000000     1.000000      0.000000     0.000000
# 25%    13818.500000     1.000000     1.000000    305.080000     0.950000
# 50%    15305.000000     2.000000     2.000000    658.760000     5.040000
# 75%    16778.250000     5.000000     4.000000   1591.602500     9.950000
# max    18287.000000    12.000000    28.000000  18895.910000  3861.000000
#
#             Median          Max
# count  4272.000000  4272.000000
# mean     26.728890   104.493432
# std     106.502767   210.394673
# min       0.000000     0.000000
# 25%       8.500000    31.800000
# 50%      15.600000    51.000000
# 75%      17.850000   102.000000
# max    3861.000000  4161.060000

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Using the elbow method to find the optimal number of clusters

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(rfm)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title("The Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("WSS")
plt.show()

# %% [markdown]
# #### There seem to be 4 optimal number of clusters

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42)
customer_clusters = kmeans.fit_predict(rfm)

# %%
rfm["Cluster"] = customer_clusters

# %%
def plot_3d(cluster):
    cluster_data = rfm[rfm['Cluster'] == cluster]
    # Create the 3D plot
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection="3d")
    
    # Scatter plot for Cluster 0
    sc = ax.scatter(xs=cluster_data['Recency'], 
                    ys=cluster_data['Frequency'], 
                    zs=cluster_data['Monetary'], 
                    c=cluster_data['Monetary'], 
                    cmap='viridis')
    
    # Labels and Title
    ax.set_xlabel("Recency")
    ax.set_ylabel("Frequency")
    ax.set_zlabel("Monetary")
    ax.set_title(f"3D Scatter Plot for Cluster {cluster}")
    
    # Show the plot
    plt.colorbar(sc)  # Adds a color bar for the scatter plot
    plt.show()

# %% [markdown]
# ### Plotting each clusters for analysis

# %%
# Filter the data once for Cluster 0
plot_3d(0)

# %%
plot_3d(1)

# %%
plot_3d(2)

# %%
plot_3d(3)

# %%
cluster_0_data = rfm[rfm['Cluster'] == 0]
cluster_1_data = rfm[rfm['Cluster'] == 1]
cluster_2_data = rfm[rfm['Cluster'] == 2]
cluster_3_data = rfm[rfm['Cluster'] == 3]

# %% [markdown]
# ### Get information about customers in the First cluster in terms of their recency, frequancy and monetary behaviour

# %%
cluster_0_data.iloc[:, 2:5].describe()
# Out:
#            Recency    Frequency     Monetary
# count  1830.000000  1830.000000  1830.000000
# mean      3.453552     2.596721   792.635498
# std       3.439356     2.125939   662.960034
# min       0.000000     1.000000     0.000000
# 25%       1.000000     1.000000   289.475000
# 50%       2.000000     2.000000   585.135000
# 75%       6.000000     3.000000  1125.742500
# max      12.000000    22.000000  3023.080000

# %% [markdown]
# ### Get information about customers in the Second cluster in terms of their recency, frequancy and monetary behaviour

# %%
cluster_1_data.iloc[:, 2:5].describe()
# Out:
#           Recency   Frequency     Monetary
# count  462.000000  462.000000   462.000000
# mean     0.963203    9.458874  4256.499634
# std      1.474567    5.188992  1304.188250
# min      0.000000    1.000000  2298.930000
# 25%      0.000000    6.000000  3237.067500
# 50%      1.000000    8.000000  3951.390000
# 75%      1.000000   12.000000  5068.997500
# max     11.000000   28.000000  7616.530000

# %% [markdown]
# ### Get information about customers in the Third cluster in terms of their recency, frequancy and monetary behaviour

# %%
cluster_2_data.iloc[:, 2:5].describe()
# Out:
#          Recency  Frequency      Monetary
# count  87.000000  87.000000     87.000000
# mean    0.609195  15.666667  11011.340000
# std     1.358490   7.037552   2811.865442
# min     0.000000   2.000000   7700.230000
# 25%     0.000000  11.000000   8685.555000
# 50%     0.000000  15.000000  10484.990000
# 75%     1.000000  20.500000  12614.885000
# max     9.000000  28.000000  18895.910000

# %% [markdown]
# ### Get information about customers in the Fourth cluster in terms of their recency, frequancy and monetary behaviour

# %%
cluster_3_data.iloc[:, 2:5].describe()
# Out:
#            Recency    Frequency     Monetary
# count  1893.000000  1893.000000  1893.000000
# mean      3.352879     2.749076   758.228348
# std       3.414021     2.301049   687.552459
# min       0.000000     1.000000     3.750000
# 25%       1.000000     1.000000   249.860000
# 50%       2.000000     2.000000   508.800000
# 75%       5.000000     4.000000  1060.250000
# max      12.000000    17.000000  3651.970000

# %% [markdown]
# ### Plotting the clusters in terms of population

# %%
sizes = [
    cluster_0_data.shape[0],  # Number of rows in cluster_0_data
    cluster_1_data.shape[0],  # Number of rows in cluster_1_data
    cluster_2_data.shape[0],  # Number of rows in cluster_2_data
    cluster_3_data.shape[0],  # Number of rows in cluster_3_data
]
labels = ['1st Cluster', '2nd Cluster', '3rd Cluster', '4th Cluster']

# Create a pie chart
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=0)

# Equal aspect ratio ensures that pie is drawn as a circle.
ax.axis('equal')

# Display the pie chart
plt.show()

# %% [markdown]
# ### Plotting the clusters in terms of money spent

# %%
sizes = [
    cluster_0_data['Monetary'].sum(),  
    cluster_1_data['Monetary'].sum(),
    cluster_2_data['Monetary'].sum(), 
    cluster_3_data['Monetary'].sum(),
]
labels = ['1st Cluster', '2nd Cluster', '3rd Cluster', '4th Cluster']

# Create a pie chart
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=0)

# Equal aspect ratio ensures that pie is drawn as a circle.
ax.axis('equal')

# Display the pie chart
plt.show()
